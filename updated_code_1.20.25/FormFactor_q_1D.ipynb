// %% [markdown]
// # Form factor functions in 1D: $|F(q)|^{2}$

// %%
#include "FormFactor_q_1D.h"

// %% [markdown]
// ### These are the parameters for all functions below

// %%
double A = 197, Vo = 2.12, R = 6.38, a0 = 0.7;
double q_min = 0, q_max = 0.5; 

// Initialize constructor
FormFactor_q_1D ff_1d(A, Vo, R, a0, q_min, q_max);

// %%
TF1 *ff_q = ff_1d.getFormFactorq_1D();
    ff_q->GetYaxis()->SetTitle("|F(q)|^{2}");
    ff_q->GetXaxis()->SetTitle("q [GeV]");
    ff_q->Draw();
gStyle->SetOptStat(0);
c1->Draw();
